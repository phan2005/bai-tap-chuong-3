# %%
import numpy as np 
with open ('D:\\BAI TAP\\CHUONG3\\heights_1.txt','r',encoding='utf-8-sig') as f:
    height=f.readlines()
    height=height[0].strip().split(',')
    list_height=list(map(lambda x:float(x),height))
print(list_height)
with open ('D:\\BAI TAP\\CHUONG3\\weights_1.txt', 'r',encoding='utf-8-sig') as f:
    weight=f.readlines()
    weight=weight[0].strip().split(',')
    list_weight=list(map(lambda x:float(x),weight))
print(list_weight)
#1
arr_height=np.array(list_height)
#2
arr_weight=np.array(list_weight)
#3
arr_height_m=[height*0.0254 for height in arr_height]
#4
arr_weight_kg=[weight*0.453592 for weight in arr_weight]
#5
arr_bmi=[weight/(height**2) for weight, height in zip(arr_weight_kg, arr_height_m)]
#6
weight_at_index_50=arr_weight_kg[50]
#7
arr_height_m_100=arr_height_m[100:111]
#8
cau_thu_bmi_nho_hon_21=[i for i, bmi in enumerate(arr_bmi) if bmi<21]
#9
chieu_cao_trung_binh=sum(arr_height_m)/len(arr_height_m)
can_nang_trung_binh=sum(arr_weight_kg)/len(arr_weight_kg)
#10
max_height=max(arr_height_m)
max_weight=max(arr_weight_kg)
#11
min_height=min(arr_height_m)
min_weight=min(arr_weight_kg)
print(arr_height)
print(arr_weight)
print(arr_height_m)
print(arr_weight_kg)
print(arr_bmi)
print(weight_at_index_50)
print(arr_height_m_100)
print(cau_thu_bmi_nho_hon_21)
print(chieu_cao_trung_binh)
print(can_nang_trung_binh)
print(max_height)
print(max_weight)
print(min_height)
print(min_weight)
# Out:
# [74.0, 74.0, 72.0, 72.0, 73.0, 69.0, 69.0, 71.0, 76.0, 71.0, 73.0, 73.0, 74.0, 74.0, 69.0, 70.0, 73.0, 75.0, 78.0, 79.0, 76.0, 74.0, 76.0, 72.0, 71.0, 75.0, 77.0, 74.0, 73.0, 74.0, 78.0, 73.0, 75.0, 73.0, 75.0, 75.0, 74.0, 69.0, 71.0, 74.0, 73.0, 73.0, 76.0, 74.0, 74.0, 70.0, 72.0, 77.0, 74.0, 70.0, 73.0, 75.0, 76.0, 76.0, 78.0, 74.0, 74.0, 76.0, 77.0, 81.0, 78.0, 75.0, 77.0, 75.0, 76.0, 74.0, 72.0, 72.0, 75.0, 73.0, 73.0, 73.0, 70.0, 70.0, 70.0, 76.0, 68.0, 71.0, 72.0, 75.0, 75.0, 75.0, 75.0, 68.0, 74.0, 78.0, 71.0, 73.0, 76.0, 74.0, 74.0, 79.0, 75.0, 73.0, 76.0, 74.0, 74.0, 73.0, 72.0, 74.0, 73.0, 74.0, 72.0, 73.0, 69.0, 72.0, 73.0, 75.0, 75.0, 73.0, 72.0, 72.0, 76.0, 74.0, 72.0, 77.0, 74.0, 77.0, 75.0, 76.0, 80.0, 74.0, 74.0, 75.0, 78.0, 73.0, 73.0, 74.0, 75.0, 76.0, 71.0, 73.0, 74.0, 76.0, 76.0, 74.0, 73.0, 74.0, 70.0, 72.0, 73.0, 73.0, 73.0, 73.0, 71.0, 74.0, 74.0, 72.0, 74.0, 71.0, 74.0, 73.0, 75.0, 75.0, 79.0, 73.0, 75.0, 76.0, 74.0, 76.0, 78.0, 74.0, 76.0, 72.0, 74.0, 76.0, 7
# ...
